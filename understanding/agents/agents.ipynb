# %%
from llama_index.core.tools import FunctionTool
from llama_index.llms.ollama import Ollama
from llama_index.core.agent import ReActAgent
from llama_index.core import Settings

Settings.llm = Ollama(model="phi", request_timeout=200.0)

# %%
# define sample Tool
def multiply(a: int, b: int) -> int:
    """Multiply two integers and returns the result integer"""
    return a * b

def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b

multiply_tool = FunctionTool.from_defaults(fn=multiply)
add_tool = FunctionTool.from_defaults(fn=add)
# initialize ReAct agent
agent = ReActAgent.from_tools([multiply_tool, add_tool], llm=Settings.llm, verbose=True)

# %%
agent.chat("What is 2 times 3?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/step.py:200, in ReActAgentWorker._extract_reasoning_step(self, output, is_streaming)
#     199 try:
# --> 200     reasoning_step = self._output_parser.parse(message_content, is_streaming)
#     201 except BaseException as exc:
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/output_parser.py:109, in ReActOutputParser.parse(self, output, is_streaming)
#     107     return parse_action_reasoning_step(output)
# --> 109 raise ValueError(f"Could not parse output: {output}")
#
# ValueError: Could not parse output:  The current language of the user is: english. I will use a tool to help me answer the question.
# Tool: multiply(a, b)
# Action Input: {"input": "2", "num_beams": 5}
# Thought: The number I need to find is 2. It needs to be multiplied by 3, so it should be 6.
# Observation: tool response: 6
#
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agent.chat("What is 2 times 3?")
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:596, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     591     tool_choice = self.default_tool_choice
#     592 with self.callback_manager.event(
#     593     CBEventType.AGENT_STEP,
#     594     payload={EventPayload.MESSAGES: [message]},
#     595 ) as e:
# --> 596     chat_response = self._chat(
#     597         message=message,
#     598         chat_history=chat_history,
#     599         tool_choice=tool_choice,
#     600         mode=ChatResponseMode.WAIT,
#     601     )
#     602     assert isinstance(chat_response, AgentChatResponse)
#     603     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:102, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#     100     result = func(*args, **kwargs)
#     101 except Exception as e:
# --> 102     self.span_drop(id=id, err=e)
#     103 else:
#     104     self.span_exit(id=id, result=result)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:77, in Dispatcher.span_drop(self, id, err, **kwargs)
#      75 while c:
#      76     for h in c.span_handlers:
# ---> 77         h.span_drop(id, err, **kwargs)
#      78     if not c.propagate:
#      79         c = None
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/span_handlers/base.py:45, in BaseSpanHandler.span_drop(self, id, err, **kwargs)
#      43 def span_drop(self, id: str, err: Optional[Exception], **kwargs) -> None:
#      44     """Logic for dropping a span i.e. early exit."""
# ---> 45     self.prepare_to_drop_span(id, err, **kwargs)
#      46     if self.current_span_id == id:
#      47         self.current_span_id = self.open_spans[id].parent_id
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/span_handlers/null.py:33, in NullSpanHandler.prepare_to_drop_span(self, id, err, **kwargs)
#      31 """Logic for droppping a span."""
#      32 if err:
# ---> 33     raise err
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(id=id, err=e)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:533, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     530 dispatcher.event(AgentChatWithStepStartEvent())
#     531 while True:
#     532     # pass step queue in as argument, assume step executor is stateless
# --> 533     cur_step_output = self._run_step(
#     534         task.task_id, mode=mode, tool_choice=tool_choice
#     535     )
#     537     if cur_step_output.is_last:
#     538         result_output = cur_step_output
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:102, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#     100     result = func(*args, **kwargs)
#     101 except Exception as e:
# --> 102     self.span_drop(id=id, err=e)
#     103 else:
#     104     self.span_exit(id=id, result=result)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:77, in Dispatcher.span_drop(self, id, err, **kwargs)
#      75 while c:
#      76     for h in c.span_handlers:
# ---> 77         h.span_drop(id, err, **kwargs)
#      78     if not c.propagate:
#      79         c = None
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/span_handlers/base.py:45, in BaseSpanHandler.span_drop(self, id, err, **kwargs)
#      43 def span_drop(self, id: str, err: Optional[Exception], **kwargs) -> None:
#      44     """Logic for dropping a span i.e. early exit."""
# ---> 45     self.prepare_to_drop_span(id, err, **kwargs)
#      46     if self.current_span_id == id:
#      47         self.current_span_id = self.open_spans[id].parent_id
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/span_handlers/null.py:33, in NullSpanHandler.prepare_to_drop_span(self, id, err, **kwargs)
#      31 """Logic for droppping a span."""
#      32 if err:
# ---> 33     raise err
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:100, in Dispatcher.span.<locals>.wrapper(*args, **kwargs)
#      98 self.span_enter(id=id, **kwargs)
#      99 try:
# --> 100     result = func(*args, **kwargs)
#     101 except Exception as e:
#     102     self.span_drop(id=id, err=e)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/runner/base.py:382, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     378 # TODO: figure out if you can dynamically swap in different step executors
#     379 # not clear when you would do that by theoretically possible
#     381 if mode == ChatResponseMode.WAIT:
# --> 382     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     383 elif mode == ChatResponseMode.STREAM:
#     384     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/step.py:609, in ReActAgentWorker.run_step(self, step, task, **kwargs)
#     606 @trace_method("run_step")
#     607 def run_step(self, step: TaskStep, task: Task, **kwargs: Any) -> TaskStepOutput:
#     608     """Run step."""
# --> 609     return self._run_step(step, task)
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/step.py:423, in ReActAgentWorker._run_step(self, step, task)
#     421 chat_response = self._llm.chat(input_chat)
#     422 # given react prompt outputs, call tools or return response
# --> 423 reasoning_steps, is_done = self._process_actions(
#     424     task, tools, output=chat_response
#     425 )
#     426 task.extra_state["current_reasoning"].extend(reasoning_steps)
#     427 agent_response = self._get_response(
#     428     task.extra_state["current_reasoning"], task.extra_state["sources"]
#     429 )
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/step.py:226, in ReActAgentWorker._process_actions(self, task, tools, output, is_streaming)
#     216 def _process_actions(
#     217     self,
#     218     task: Task,
#    (...)
#     221     is_streaming: bool = False,
#     222 ) -> Tuple[List[BaseReasoningStep], bool]:
#     223     tools_dict: Dict[str, AsyncBaseTool] = {
#     224         tool.metadata.get_name(): tool for tool in tools
#     225     }
# --> 226     _, current_reasoning, is_done = self._extract_reasoning_step(
#     227         output, is_streaming
#     228     )
#     230     if is_done:
#     231         return current_reasoning, True
#
# File ~/NLP/lib/python3.11/site-packages/llama_index/core/agent/react/step.py:202, in ReActAgentWorker._extract_reasoning_step(self, output, is_streaming)
#     200     reasoning_step = self._output_parser.parse(message_content, is_streaming)
#     201 except BaseException as exc:
# --> 202     raise ValueError(f"Could not parse output: {message_content}") from exc
#     203 if self._verbose:
#     204     print_text(f"{reasoning_step.get_content()}\n", color="pink")
#
# ValueError: Could not parse output:  The current language of the user is: english. I will use a tool to help me answer the question.
# Tool: multiply(a, b)
# Action Input: {"input": "2", "num_beams": 5}
# Thought: The number I need to find is 2. It needs to be multiplied by 3, so it should be 6.
# Observation: tool response: 6
